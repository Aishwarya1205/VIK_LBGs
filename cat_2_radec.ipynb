# %%
import pandas as pd

# --------------------------------------------------
# Paths
# --------------------------------------------------
input_file = "/Users/aishwarya/Documents/Lyman_alpha/CDFS_candidates_ZY_degraded.cat"
output_file = "/Users/aishwarya/Documents/Lyman_alpha/CDFS_candidates_ZY_degraded_RADEC.txt"

# --------------------------------------------------
# Read CSV file
# --------------------------------------------------
df = pd.read_csv(input_file)

# --------------------------------------------------
# Extract only RA and DEC
# --------------------------------------------------
radec_df = df[["RA", "DEC"]]

# --------------------------------------------------
# Save as space-separated txt
# --------------------------------------------------
radec_df.to_csv(output_file, sep=" ", index=False, header=False)

print(f"Saved RA/Dec file to: {output_file}")
# Out:
# Saved RA/Dec file to: /Users/aishwarya/Documents/Lyman_alpha/CDFS_candidates_ZY_degraded_RADEC.txt
